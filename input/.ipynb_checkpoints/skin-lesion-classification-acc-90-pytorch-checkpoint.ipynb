# %% [markdown]
# This is a very interesting task and it's very suitable for beginners, through this task you can learn about data analysis, data processing, model building, model training, parameter optimization and so on. When only use the images, with a common network, such as Resnet, Densenet, you can achieve a relatively good accuracy very easily.
#
# By analyzing the data, the basic information of the patient is also related to the classification of the diseased tissue. Therefore, if we can combine the case information to carry out the classification task, it will be a very meaningful work. Actually during clinical diagnosis, doctors will also combine different modal data to make comprehensive judgments.
#
# Due to the urgency of time, my current method only uses image data, and then I will consider adding the patient's personal information to the classification task to train a more complete model. I will update my kernel immediately once I finished.
#
# Before you really start, I strongly recommend you to read the material of pigmented lesions and dermatoscopic images[https://arxiv.org/abs/1803.10417]. After that, you can learn about the characteristics and distribution of the data from the task description and this kernel[https://www.kaggle.com/kmader/dermatology-mnist-loading-and-processing]
#
# In this kernel I have followed following steps for model building and evaluation:
#
# > Step 1. Data analysis and preprocessing
#
# > Step 2. Model building
#
# > Step 3. Model training
#
# > Step 4. Model evaluation
#
# I used the pytorch framework to complete the entire task. The code contains several common networks, such as Resnet, VGG, Densenet, and Inception. You only need to make minor changes on the code to complete the network switch. Without the hyperparameter adjustment, I used **Densenet-121 to achieve an accuracy of more than 90% on the validation set in 10 epochs.**

# %% [markdown]
#  ### First, import all libraries that used in this project

# %%
# %matplotlib inline
# python libraties
import os, cv2,itertools
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from tqdm import tqdm
from glob import glob
from PIL import Image

# pytorch libraries
import torch
from torch import optim,nn
from torch.autograd import Variable
from torch.utils.data import DataLoader,Dataset
from torchvision import models,transforms

# sklearn libraries
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# to make the results are reproducible
np.random.seed(10)
torch.manual_seed(10)
torch.cuda.manual_seed(10)

print(os.listdir("../input"))
# Out:
# ['.ipynb_checkpoints', 'archive', 'skin-lesion-classification-acc-90-pytorch.ipynb', 'test_database']

# %% [markdown]
# ## Step 1. Data analysis and preprocessing

# %% [markdown]
# Get the all image data paths, match the row information in HAM10000_metadata.csv with its corresponding image

# %%
data_dir = '../input/archive' #database directory
all_image_path = glob(os.path.join(data_dir, '*', '*.jpg')) #find all files with jpg extension in database directory
imageid_path_dict = {os.path.splitext(os.path.basename(x))[0]: x for x in all_image_path} #map base filaname to its path

#TODO: this might be modified to only accomodate for malignant vs benign tumors
lesion_type_dict = {
    'nv': 'Melanocytic nevi',
    'mel': 'Melanoma',
    'bkl': 'Benign keratosis-like lesions ',
    'bcc': 'Basal cell carcinoma',
    'akiec': 'Actinic keratoses',
    'vasc': 'Vascular lesions',
    'df': 'Dermatofibroma'
}

# %%
imageid_path_dict
# Out:
# {'ISIC_0024306': '../input/test_database\\images\\ISIC_0024306.jpg',
#  'ISIC_0024307': '../input/test_database\\images\\ISIC_0024307.jpg',
#  'ISIC_0024308': '../input/test_database\\images\\ISIC_0024308.jpg',
#  'ISIC_0024309': '../input/test_database\\images\\ISIC_0024309.jpg',
#  'ISIC_0024310': '../input/test_database\\images\\ISIC_0024310.jpg',
#  'ISIC_0024311': '../input/test_database\\images\\ISIC_0024311.jpg',
#  'ISIC_0024312': '../input/test_database\\images\\ISIC_0024312.jpg',
#  'ISIC_0024313': '../input/test_database\\images\\ISIC_0024313.jpg',
#  'ISIC_0024314': '../input/test_database\\images\\ISIC_0024314.jpg',
#  'ISIC_0024315': '../input/test_database\\images\\ISIC_0024315.jpg',
#  'ISIC_0024316': '../input/test_database\\images\\ISIC_0024316.jpg',
#  'ISIC_0025077': '../input/test_database\\images\\ISIC_0025077.jpg',
#  'ISIC_0025078': '../input/test_database\\images\\ISIC_0025078.jpg',
#  'ISIC_0025079': '../input/test_database\\images\\ISIC_0025079.jpg',
#  'ISIC_0025080': '../input/test_database\\images\\ISIC_0025080.jpg',
#  'ISIC_0025081': '../input/test_database\\images\\ISIC_0025081.jpg',
#  'ISIC_0025082': '../input/test_database\\images\\ISIC_0025082.jpg',
#  'ISIC_0025083': '../input/test_database\\images\\ISIC_0025083.jpg',
#  'ISIC_0025084': '../input/test_database\\images\\ISIC_0025084.jpg',
#  'ISIC_0025085': '../input/test_database\\images\\ISIC_0025085.jpg',
#  'ISIC_0025086': '../input/test_database\\images\\ISIC_0025086.jpg',
#  'ISIC_0025087': '../input/test_database\\images\\ISIC_0025087.jpg',
#  'ISIC_0025088': '../input/test_database\\images\\ISIC_0025088.jpg',
#  'ISIC_0025089': '../input/test_database\\images\\ISIC_0025089.jpg',
#  'ISIC_0025090': '../input/test_database\\images\\ISIC_0025090.jpg',
#  'ISIC_0025091': '../input/test_database\\images\\ISIC_0025091.jpg',
#  'ISIC_0025092': '../input/test_database\\images\\ISIC_0025092.jpg',
#  'ISIC_0025093': '../input/test_database\\images\\ISIC_0025093.jpg',
#  'ISIC_0025094': '../input/test_database\\images\\ISIC_0025094.jpg',
#  'ISIC_0025095': '../input/test_database\\images\\ISIC_0025095.jpg',
#  'ISIC_0025096': '../input/test_database\\images\\ISIC_0025096.jpg',
#  'ISIC_0025097': '../input/test_database\\images\\ISIC_0025097.jpg',
#  'ISIC_0025098': '../input/test_database\\images\\ISIC_0025098.jpg',
#  'ISIC_0025099': '../input/test_database\\images\\ISIC_0025099.jpg',
#  'ISIC_0025100': '../input/test_database\\images\\ISIC_0025100.jpg',
#  'ISIC_0025101': '../input/test_database\\images\\ISIC_0025101.jpg',
#  'ISIC_0025102': '../input/test_database\\images\\ISIC_0025102.jpg',
#  'ISIC_0025103': '../input/test_database\\images\\ISIC_0025103.jpg',
#  'ISIC_0025104': '../input/test_database\\images\\ISIC_0025104.jpg',
#  'ISIC_0025105': '../input/test_database\\images\\ISIC_0025105.jpg',
#  'ISIC_0025106': '../input/test_database\\images\\ISIC_0025106.jpg',
#  'ISIC_0025107': '../input/test_database\\images\\ISIC_0025107.jpg',
#  'ISIC_0025108': '../input/test_database\\images\\ISIC_0025108.jpg',
#  'ISIC_0025109': '../input/test_database\\images\\ISIC_0025109.jpg',
#  'ISIC_0025110': '../input/test_database\\images\\ISIC_0025110.jpg',
#  'ISIC_0025111': '../input/test_database\\images\\ISIC_0025111.jpg',
#  'ISIC_0025112': '../input/test_database\\images\\ISIC_0025112.jpg',
#  'ISIC_0025113': '../input/test_database\\images\\ISIC_0025113.jpg',
#  'ISIC_0025114': '../input/test_database\\images\\ISIC_0025114.jpg',
#  'ISIC_0025115': '../input/test_database\\images\\ISIC_0025115.jpg',
#  'ISIC_0025116': '../input/test_database\\images\\ISIC_0025116.jpg',
#  'ISIC_0025117': '../input/test_database\\images\\ISIC_0025117.jpg',
#  'ISIC_0025118': '../input/test_database\\images\\ISIC_0025118.jpg',
#  'ISIC_0025119': '../input/test_database\\images\\ISIC_0025119.jpg',
#  'ISIC_0025120': '../input/test_database\\images\\ISIC_0025120.jpg',
#  'ISIC_0025121': '../input/test_database\\images\\ISIC_0025121.jpg',
#  'ISIC_0025122': '../input/test_database\\images\\ISIC_0025122.jpg',
#  'ISIC_0025123': '../input/test_database\\images\\ISIC_0025123.jpg',
#  'ISIC_0025124': '../input/test_database\\images\\ISIC_0025124.jpg',
#  'ISIC_0025125': '../input/test_database\\images\\ISIC_0025125.jpg',
#  'ISIC_0025126': '../input/test_database\\images\\ISIC_0025126.jpg',
#  'ISIC_0025127': '../input/test_database\\images\\ISIC_0025127.jpg',
#  'ISIC_0025128': '../input/test_database\\images\\ISIC_0025128.jpg',
#  'ISIC_0025129': '../input/test_database\\images\\ISIC_0025129.jpg',
#  'ISIC_0025130': '../input/test_database\\images\\ISIC_0025130.jpg',
#  'ISIC_0025131': '../input/test_database\\images\\ISIC_0025131.jpg',
#  'ISIC_0025132': '../input/test_database\\images\\ISIC_0025132.jpg',
#  'ISIC_0025133': '../input/test_database\\images\\ISIC_0025133.jpg',
#  'ISIC_0025134': '../input/test_database\\images\\ISIC_0025134.jpg',
#  'ISIC_0025135': '../input/test_database\\images\\ISIC_0025135.jpg',
#  'ISIC_0025136': '../input/test_database\\images\\ISIC_0025136.jpg',
#  'ISIC_0025137': '../input/test_database\\images\\ISIC_0025137.jpg',
#  'ISIC_0025138': '../input/test_database\\images\\ISIC_0025138.jpg',
#  'ISIC_0025139': '../input/test_database\\images\\ISIC_0025139.jpg',
#  'ISIC_0025140': '../input/test_database\\images\\ISIC_0025140.jpg',
#  'ISIC_0025141': '../input/test_database\\images\\ISIC_0025141.jpg',
#  'ISIC_0025142': '../input/test_database\\images\\ISIC_0025142.jpg',
#  'ISIC_0025143': '../input/test_database\\images\\ISIC_0025143.jpg',
#  'ISIC_0025144': '../input/test_database\\images\\ISIC_0025144.jpg',
#  'ISIC_0025145': '../input/test_database\\images\\ISIC_0025145.jpg',
#  'ISIC_0025146': '../input/test_database\\images\\ISIC_0025146.jpg',
#  'ISIC_0025147': '../input/test_database\\images\\ISIC_0025147.jpg',
#  'ISIC_0025148': '../input/test_database\\images\\ISIC_0025148.jpg',
#  'ISIC_0025149': '../input/test_database\\images\\ISIC_0025149.jpg',
#  'ISIC_0025150': '../input/test_database\\images\\ISIC_0025150.jpg',
#  'ISIC_0025151': '../input/test_database\\images\\ISIC_0025151.jpg',
#  'ISIC_0025152': '../input/test_database\\images\\ISIC_0025152.jpg',
#  'ISIC_0025153': '../input/test_database\\images\\ISIC_0025153.jpg',
#  'ISIC_0025154': '../input/test_database\\images\\ISIC_0025154.jpg',
#  'ISIC_0025155': '../input/test_database\\images\\ISIC_0025155.jpg',
#  'ISIC_0025156': '../input/test_database\\images\\ISIC_0025156.jpg',
#  'ISIC_0025157': '../input/test_database\\images\\ISIC_0025157.jpg',
#  'ISIC_0025158': '../input/test_database\\images\\ISIC_0025158.jpg',
#  'ISIC_0025159': '../input/test_database\\images\\ISIC_0025159.jpg',
#  'ISIC_0025160': '../input/test_database\\images\\ISIC_0025160.jpg',
#  'ISIC_0025161': '../input/test_database\\images\\ISIC_0025161.jpg',
#  'ISIC_0025162': '../input/test_database\\images\\ISIC_0025162.jpg',
#  'ISIC_0025163': '../input/test_database\\images\\ISIC_0025163.jpg',
#  'ISIC_0025164': '../input/test_database\\images\\ISIC_0025164.jpg',
#  'ISIC_0025165': '../input/test_database\\images\\ISIC_0025165.jpg',
#  'ISIC_0025166': '../input/test_database\\images\\ISIC_0025166.jpg',
#  'ISIC_0025167': '../input/test_database\\images\\ISIC_0025167.jpg',
#  'ISIC_0025168': '../input/test_database\\images\\ISIC_0025168.jpg',
#  'ISIC_0025169': '../input/test_database\\images\\ISIC_0025169.jpg',
#  'ISIC_0025170': '../input/test_database\\images\\ISIC_0025170.jpg',
#  'ISIC_0025171': '../input/test_database\\images\\ISIC_0025171.jpg',
#  'ISIC_0025172': '../input/test_database\\images\\ISIC_0025172.jpg',
#  'ISIC_0025173': '../input/test_database\\images\\ISIC_0025173.jpg',
#  'ISIC_0025174': '../input/test_database\\images\\ISIC_0025174.jpg',
#  'ISIC_0025175': '../input/test_database\\images\\ISIC_0025175.jpg',
#  'ISIC_0025176': '../input/test_database\\images\\ISIC_0025176.jpg',
#  'ISIC_0025177': '../input/test_database\\images\\ISIC_0025177.jpg',
#  'ISIC_0025178': '../input/test_database\\images\\ISIC_0025178.jpg',
#  'ISIC_0025179': '../input/test_database\\images\\ISIC_0025179.jpg',
#  'ISIC_0025180': '../input/test_database\\images\\ISIC_0025180.jpg',
#  'ISIC_0025181': '../input/test_database\\images\\ISIC_0025181.jpg',
#  'ISIC_0025182': '../input/test_database\\images\\ISIC_0025182.jpg',
#  'ISIC_0025183': '../input/test_database\\images\\ISIC_0025183.jpg',
#  'ISIC_0025184': '../input/test_database\\images\\ISIC_0025184.jpg',
#  'ISIC_0025185': '../input/test_database\\images\\ISIC_0025185.jpg',
#  'ISIC_0025186': '../input/test_database\\images\\ISIC_0025186.jpg',
#  'ISIC_0025187': '../input/test_database\\images\\ISIC_0025187.jpg',
#  'ISIC_0025188': '../input/test_database\\images\\ISIC_0025188.jpg',
#  'ISIC_0025189': '../input/test_database\\images\\ISIC_0025189.jpg',
#  'ISIC_0025190': '../input/test_database\\images\\ISIC_0025190.jpg',
#  'ISIC_0025191': '../input/test_database\\images\\ISIC_0025191.jpg',
#  'ISIC_0025192': '../input/test_database\\images\\ISIC_0025192.jpg',
#  'ISIC_0025193': '../input/test_database\\images\\ISIC_0025193.jpg',
#  'ISIC_0025194': '../input/test_database\\images\\ISIC_0025194.jpg',
#  'ISIC_0025195': '../input/test_database\\images\\ISIC_0025195.jpg',
#  'ISIC_0025196': '../input/test_database\\images\\ISIC_0025196.jpg',
#  'ISIC_0025197': '../input/test_database\\images\\ISIC_0025197.jpg',
#  'ISIC_0025198': '../input/test_database\\images\\ISIC_0025198.jpg',
#  'ISIC_0025199': '../input/test_database\\images\\ISIC_0025199.jpg',
#  'ISIC_0025200': '../input/test_database\\images\\ISIC_0025200.jpg',
#  'ISIC_0025201': '../input/test_database\\images\\ISIC_0025201.jpg',
#  'ISIC_0025202': '../input/test_database\\images\\ISIC_0025202.jpg',
#  'ISIC_0025203': '../input/test_database\\images\\ISIC_0025203.jpg',
#  'ISIC_0025204': '../input/test_database\\images\\ISIC_0025204.jpg',
#  'ISIC_0025205': '../input/test_database\\images\\ISIC_0025205.jpg',
#  'ISIC_0025206': '../input/test_database\\images\\ISIC_0025206.jpg',
#  'ISIC_0025207': '../input/test_database\\images\\ISIC_0025207.jpg',
#  'ISIC_0025208': '../input/test_database\\images\\ISIC_0025208.jpg',
#  'ISIC_0025209': '../input/test_database\\images\\ISIC_0025209.jpg',
#  'ISIC_0025210': '../input/test_database\\images\\ISIC_0025210.jpg',
#  'ISIC_0025211': '../input/test_database\\images\\ISIC_0025211.jpg',
#  'ISIC_0025212': '../input/test_database\\images\\ISIC_0025212.jpg',
#  'ISIC_0025213': '../input/test_database\\images\\ISIC_0025213.jpg',
#  'ISIC_0025214': '../input/test_database\\images\\ISIC_0025214.jpg',
#  'ISIC_0025215': '../input/test_database\\images\\ISIC_0025215.jpg',
#  'ISIC_0025216': '../input/test_database\\images\\ISIC_0025216.jpg',
#  'ISIC_0025217': '../input/test_database\\images\\ISIC_0025217.jpg',
#  'ISIC_0025218': '../input/test_database\\images\\ISIC_0025218.jpg',
#  'ISIC_0025219': '../input/test_database\\images\\ISIC_0025219.jpg',
#  'ISIC_0025220': '../input/test_database\\images\\ISIC_0025220.jpg',
#  'ISIC_0025221': '../input/test_database\\images\\ISIC_0025221.jpg',
#  'ISIC_0025222': '../input/test_database\\images\\ISIC_0025222.jpg',
#  'ISIC_0025223': '../input/test_database\\images\\ISIC_0025223.jpg',
#  'ISIC_0025224': '../input/test_database\\images\\ISIC_0025224.jpg',
#  'ISIC_0025225': '../input/test_database\\images\\ISIC_0025225.jpg',
#  'ISIC_0025226': '../input/test_database\\images\\ISIC_0025226.jpg',
#  'ISIC_0025227': '../input/test_database\\images\\ISIC_0025227.jpg',
#  'ISIC_0025228': '../input/test_database\\images\\ISIC_0025228.jpg',
#  'ISIC_0025229': '../input/test_database\\images\\ISIC_0025229.jpg',
#  'ISIC_0025230': '../input/test_database\\images\\ISIC_0025230.jpg',
#  'ISIC_0025231': '../input/test_database\\images\\ISIC_0025231.jpg',
#  'ISIC_0025232': '../input/test_database\\images\\ISIC_0025232.jpg',
#  'ISIC_0025233': '../input/test_database\\images\\ISIC_0025233.jpg',
#  'ISIC_0025234': '../input/test_database\\images\\ISIC_0025234.jpg',
#  'ISIC_0025235': '../input/test_database\\images\\ISIC_0025235.jpg',
#  'ISIC_0025236': '../input/test_database\\images\\ISIC_0025236.jpg',
#  'ISIC_0025237': '../input/test_database\\images\\ISIC_0025237.jpg',
#  'ISIC_0025238': '../input/test_database\\images\\ISIC_0025238.jpg',
#  'ISIC_0025239': '../input/test_database\\images\\ISIC_0025239.jpg',
#  'ISIC_0025240': '../input/test_database\\images\\ISIC_0025240.jpg',
#  'ISIC_0025241': '../input/test_database\\images\\ISIC_0025241.jpg',
#  'ISIC_0025242': '../input/test_database\\images\\ISIC_0025242.jpg',
#  'ISIC_0025243': '../input/test_database\\images\\ISIC_0025243.jpg',
#  'ISIC_0025244': '../input/test_database\\images\\ISIC_0025244.jpg',
#  'ISIC_0025245': '../input/test_database\\images\\ISIC_0025245.jpg',
#  'ISIC_0025246': '../input/test_database\\images\\ISIC_0025246.jpg',
#  'ISIC_0025247': '../input/test_database\\images\\ISIC_0025247.jpg',
#  'ISIC_0025248': '../input/test_database\\images\\ISIC_0025248.jpg',
#  'ISIC_0025249': '../input/test_database\\images\\ISIC_0025249.jpg',
#  'ISIC_0025250': '../input/test_database\\images\\ISIC_0025250.jpg',
#  'ISIC_0025251': '../input/test_database\\images\\ISIC_0025251.jpg',
#  'ISIC_0025252': '../input/test_database\\images\\ISIC_0025252.jpg',
#  'ISIC_0025253': '../input/test_database\\images\\ISIC_0025253.jpg',
#  'ISIC_0025254': '../input/test_database\\images\\ISIC_0025254.jpg',
#  'ISIC_0025255': '../input/test_database\\images\\ISIC_0025255.jpg',
#  'ISIC_0025256': '../input/test_database\\images\\ISIC_0025256.jpg',
#  'ISIC_0025257': '../input/test_database\\images\\ISIC_0025257.jpg',
#  'ISIC_0025258': '../input/test_database\\images\\ISIC_0025258.jpg',
#  'ISIC_0025259': '../input/test_database\\images\\ISIC_0025259.jpg',
#  'ISIC_0025260': '../input/test_database\\images\\ISIC_0025260.jpg',
#  'ISIC_0025261': '../input/test_database\\images\\ISIC_0025261.jpg',
#  'ISIC_0025262': '../input/test_database\\images\\ISIC_0025262.jpg',
#  'ISIC_0025263': '../input/test_database\\images\\ISIC_0025263.jpg',
#  'ISIC_0025264': '../input/test_database\\images\\ISIC_0025264.jpg',
#  'ISIC_0025265': '../input/test_database\\images\\ISIC_0025265.jpg',
#  'ISIC_0025266': '../input/test_database\\images\\ISIC_0025266.jpg',
#  'ISIC_0025267': '../input/test_database\\images\\ISIC_0025267.jpg',
#  'ISIC_0025268': '../input/test_database\\images\\ISIC_0025268.jpg',
#  'ISIC_0025269': '../input/test_database\\images\\ISIC_0025269.jpg',
#  'ISIC_0025270': '../input/test_database\\images\\ISIC_0025270.jpg',
#  'ISIC_0025271': '../input/test_database\\images\\ISIC_0025271.jpg',
#  'ISIC_0025272': '../input/test_database\\images\\ISIC_0025272.jpg',
#  'ISIC_0025273': '../input/test_database\\images\\ISIC_0025273.jpg',
#  'ISIC_0025274': '../input/test_database\\images\\ISIC_0025274.jpg',
#  'ISIC_0025275': '../input/test_database\\images\\ISIC_0025275.jpg',
#  'ISIC_0025276': '../input/test_database\\images\\ISIC_0025276.jpg',
#  'ISIC_0025277': '../input/test_database\\images\\ISIC_0025277.jpg',
#  'ISIC_0025278': '../input/test_database\\images\\ISIC_0025278.jpg',
#  'ISIC_0025279': '../input/test_database\\images\\ISIC_0025279.jpg',
#  'ISIC_0025280': '../input/test_database\\images\\ISIC_0025280.jpg',
#  'ISIC_0025281': '../input/test_database\\images\\ISIC_0025281.jpg',
#  'ISIC_0025282': '../input/test_database\\images\\ISIC_0025282.jpg',
#  'ISIC_0025283': '../input/test_database\\images\\ISIC_0025283.jpg',
#  'ISIC_0025284': '../input/test_database\\images\\ISIC_0025284.jpg',
#  'ISIC_0025285': '../input/test_database\\images\\ISIC_0025285.jpg',
#  'ISIC_0025286': '../input/test_database\\images\\ISIC_0025286.jpg',
#  'ISIC_0025287': '../input/test_database\\images\\ISIC_0025287.jpg',
#  'ISIC_0025288': '../input/test_database\\images\\ISIC_0025288.jpg',
#  'ISIC_0025289': '../input/test_database\\images\\ISIC_0025289.jpg',
#  'ISIC_0025290': '../input/test_database\\images\\ISIC_0025290.jpg',
#  'ISIC_0025291': '../input/test_database\\images\\ISIC_0025291.jpg',
#  'ISIC_0025292': '../input/test_database\\images\\ISIC_0025292.jpg',
#  'ISIC_0025293': '../input/test_database\\images\\ISIC_0025293.jpg',
#  'ISIC_0025294': '../input/test_database\\images\\ISIC_0025294.jpg',
#  'ISIC_0025295': '../input/test_database\\images\\ISIC_0025295.jpg',
#  'ISIC_0025296': '../input/test_database\\images\\ISIC_0025296.jpg',
#  'ISIC_0025297': '../input/test_database\\images\\ISIC_0025297.jpg',
#  'ISIC_0025298': '../input/test_database\\images\\ISIC_0025298.jpg',
#  'ISIC_0025299': '../input/test_database\\images\\ISIC_0025299.jpg',
#  'ISIC_0025300': '../input/test_database\\images\\ISIC_0025300.jpg',
#  'ISIC_0025301': '../input/test_database\\images\\ISIC_0025301.jpg',
#  'ISIC_0025302': '../input/test_database\\images\\ISIC_0025302.jpg',
#  'ISIC_0025303': '../input/test_database\\images\\ISIC_0025303.jpg',
#  'ISIC_0025304': '../input/test_database\\images\\ISIC_0025304.jpg',
#  'ISIC_0025305': '../input/test_database\\images\\ISIC_0025305.jpg'}

# %% [markdown]
# This function is used to compute the mean and standard deviation on the whole dataset, will use for inputs normalization

# %%
def compute_img_mean_std(image_paths):
    """
        computing the mean and std of three channel on the whole dataset,
        first we should normalize the image from 0-255 to 0-1
    """

    img_h, img_w = 224, 224
    imgs = []
    means, stdevs = [], []

    for i in tqdm(range(len(image_paths))):
        img = cv2.imread(image_paths[i])
        img = cv2.resize(img, (img_h, img_w))
        imgs.append(img)

    imgs = np.stack(imgs, axis=3)
    print(imgs.shape)

    imgs = imgs.astype(np.float32) / 255.

    for i in range(3):
        pixels = imgs[:, :, i, :].ravel()  # resize to one row
        means.append(np.mean(pixels))
        stdevs.append(np.std(pixels))

    means.reverse()  # BGR --> RGB
    stdevs.reverse()

    print("normMean = {}".format(means))
    print("normStd = {}".format(stdevs))
    return means,stdevs

# %% [markdown]
# Return the mean and std of RGB channels

# %%
norm_mean,norm_std = compute_img_mean_std(all_image_path)
# Out:
#  89%|████████████████████████████████████████████████████████████████████▏        | 8875/10015 [02:22<00:18, 62.61it/s]

# %% [markdown]
# Add three columns to the original DataFrame:
# -path (image path)
# -cell_type (the whole name),
# -cell_type_idx (the corresponding index  of cell type, as the image label )

# %%
df_original = pd.read_csv(os.path.join(data_dir, 'subset_metadata.csv'))
df_original['path'] = df_original['image_id'].map(imageid_path_dict.get)
df_original['cell_type'] = df_original['dx'].map(lesion_type_dict.get)
df_original['cell_type_idx'] = pd.Categorical(df_original['cell_type']).codes
df_original.head()
# Out:
#      lesion_id      image_id   dx dx_type   age     sex localization  \
# 0  HAM_0000118  ISIC_0025030  bkl   histo  80.0    male        scalp
# 1  HAM_0005132  ISIC_0025209  bkl   histo  70.0  female         back
# 2  HAM_0001396  ISIC_0025276  bkl   histo  55.0  female        trunk
# 3  HAM_0003301  ISIC_0025033  bkl   histo  60.0    male         back
# 4  HAM_0005612  ISIC_0024981  bkl   histo  80.0    male        scalp
#
#                                              path  \
# 0  ../input/test_database\images\ISIC_0025030.jpg
# 1  ../input/test_database\images\ISIC_0025209.jpg
# 2  ../input/test_database\images\ISIC_0025276.jpg
# 3  ../input/test_database\images\ISIC_0025033.jpg
# 4  ../input/test_database\images\ISIC_0024981.jpg
#
#                         cell_type  cell_type_idx
# 0  Benign keratosis-like lesions               2
# 1  Benign keratosis-like lesions               2
# 2  Benign keratosis-like lesions               2
# 3  Benign keratosis-like lesions               2
# 4  Benign keratosis-like lesions               2

# %%
len(df_original)
# Out:
# 1000

# %%
# this will tell us how many images are associated with each lesion_id
df_undup = df_original.groupby('lesion_id').count()
# now we filter out lesion_id's that have only one image associated with it
df_undup = df_undup[df_undup['image_id'] == 1]
df_undup.reset_index(inplace=True)
df_undup.head()
print(len(df_undup))
# Out:
# 955

# %%
# here we identify lesion_id's that have duplicate images and those that have only one image.
def get_duplicates(x):
    unique_list = list(df_undup['lesion_id'])
    if x in unique_list:
        return 'unduplicated'
    else:
        return 'duplicated'

# create a new colum that is a copy of the lesion_id column
df_original['duplicates'] = df_original['lesion_id']
# apply the function to this new column
df_original['duplicates'] = df_original['duplicates'].apply(get_duplicates)
df_original.head()
# Out:
#      lesion_id      image_id   dx dx_type   age     sex localization  \
# 0  HAM_0000118  ISIC_0025030  bkl   histo  80.0    male        scalp
# 1  HAM_0005132  ISIC_0025209  bkl   histo  70.0  female         back
# 2  HAM_0001396  ISIC_0025276  bkl   histo  55.0  female        trunk
# 3  HAM_0003301  ISIC_0025033  bkl   histo  60.0    male         back
# 4  HAM_0005612  ISIC_0024981  bkl   histo  80.0    male        scalp
#
#                                              path  \
# 0  ../input/test_database\images\ISIC_0025030.jpg
# 1  ../input/test_database\images\ISIC_0025209.jpg
# 2  ../input/test_database\images\ISIC_0025276.jpg
# 3  ../input/test_database\images\ISIC_0025033.jpg
# 4  ../input/test_database\images\ISIC_0024981.jpg
#
#                         cell_type  cell_type_idx    duplicates
# 0  Benign keratosis-like lesions               2  unduplicated
# 1  Benign keratosis-like lesions               2  unduplicated
# 2  Benign keratosis-like lesions               2  unduplicated
# 3  Benign keratosis-like lesions               2  unduplicated
# 4  Benign keratosis-like lesions               2  unduplicated

# %%
df_original['duplicates'].value_counts()
# Out:
# unduplicated    955
# duplicated       45
# Name: duplicates, dtype: int64

# %%
# now we filter out images that don't have duplicates
df_undup = df_original[df_original['duplicates'] == 'unduplicated']
df_undup.shape
# Out:
# (955, 11)

# %%
# now we create a validation set using df because we are sure that none of these images have augmented duplicates in the train set
y = df_undup['cell_type_idx']
_, df_val = train_test_split(df_undup, test_size=0.2, random_state=101, stratify=y)
df_val.shape
# Out:
# (191, 11)

# %%
df_val['cell_type_idx'].value_counts()
# Out:
# 4    133
# 2     20
# 6     16
# 1     10
# 0      7
# 5      3
# 3      2
# Name: cell_type_idx, dtype: int64

# %%
# This set will be df_original excluding all rows that are in the val set
# This function identifies if an image is part of the train or val set.
def get_val_rows(x):
    # create a list of all the lesion_id's in the val set
    val_list = list(df_val['image_id'])
    if str(x) in val_list:
        return 'val'
    else:
        return 'train'

# identify train and val rows
# create a new colum that is a copy of the image_id column
df_original['train_or_val'] = df_original['image_id']
# apply the function to this new column
df_original['train_or_val'] = df_original['train_or_val'].apply(get_val_rows)
# filter out train rows
df_train = df_original[df_original['train_or_val'] == 'train']
print(len(df_train))
print(len(df_val))
# Out:
# 809
# 191

# %%
df_train['cell_type_idx'].value_counts()
# Out:
# 4    552
# 2     91
# 6     75
# 1     42
# 0     29
# 5     11
# 3      9
# Name: cell_type_idx, dtype: int64

# %%
df_val['cell_type'].value_counts()
# Out:
# Melanocytic nevi                  133
# Benign keratosis-like lesions      20
# dermatofibroma                     16
# Basal cell carcinoma               10
# Actinic keratoses                   7
# Vascular lesions                    3
# Dermatofibroma                      2
# Name: cell_type, dtype: int64

# %% [markdown]
# **From From the above statistics of each category, we can see that there is a serious class imbalance in the training data. To solve this problem, I think we can start from two aspects, one is equalization sampling, and the other is a loss function that can be used to mitigate category imbalance during training, such as focal loss.**

# %%
# Copy fewer class to balance the number of 7 classes
data_aug_rate = [15,10,5,50,0,40,5]
for i in range(7):
    if data_aug_rate[i]:
        df_train=df_train.append([df_train.loc[df_train['cell_type_idx'] == i,:]]*(data_aug_rate[i]-1), ignore_index=True)
df_train['cell_type'].value_counts()
# Out:
# Melanocytic nevi                  552
# Benign keratosis-like lesions     455
# Dermatofibroma                    450
# Vascular lesions                  440
# Actinic keratoses                 435
# Basal cell carcinoma              420
# dermatofibroma                    375
# Name: cell_type, dtype: int64

# %% [markdown]
# At the beginning, I divided the data into three parts, training set, validation set and test set. Considering the small amount of data, I did not further divide the validation set data in practice.

# %%
# # We can split the test set again in a validation set and a true test set:
# df_val, df_test = train_test_split(df_val, test_size=0.5)
df_train = df_train.reset_index()
df_val = df_val.reset_index()
# df_test = df_test.reset_index()

# %%
len(df_train)
# Out:
# 3127

# %% [markdown]
# ## Step 2. Model building

# %%
# feature_extract is a boolean that defines if we are finetuning or feature extracting. 
# If feature_extract = False, the model is finetuned and all model parameters are updated. 
# If feature_extract = True, only the last layer parameters are updated, the others remain fixed.
def set_parameter_requires_grad(model, feature_extracting):
    if feature_extracting:
        for param in model.parameters():
            param.requires_grad = False

# %%
def initialize_model(model_name, num_classes, feature_extract, use_pretrained=True):
    # Initialize these variables which will be set in this if statement. Each of these
    #   variables is model specific.
    model_ft = None
    input_size = 0

    if model_name == "resnet":
        """ Resnet18, resnet34, resnet50, resnet101
        """
        model_ft = models.resnet50(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        num_ftrs = model_ft.fc.in_features
        model_ft.fc = nn.Linear(num_ftrs, num_classes)
        input_size = 224


    elif model_name == "vgg":
        """ VGG11_bn
        """
        model_ft = models.vgg11_bn(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        num_ftrs = model_ft.classifier[6].in_features
        model_ft.classifier[6] = nn.Linear(num_ftrs,num_classes)
        input_size = 224


    elif model_name == "densenet":
        """ Densenet121
        """
        model_ft = models.densenet121(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        num_ftrs = model_ft.classifier.in_features
        model_ft.classifier = nn.Linear(num_ftrs, num_classes)
        input_size = 224

    elif model_name == "inception":
        """ Inception v3
        Be careful, expects (299,299) sized images and has auxiliary output
        """
        model_ft = models.inception_v3(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        # Handle the auxilary net
        num_ftrs = model_ft.AuxLogits.fc.in_features
        model_ft.AuxLogits.fc = nn.Linear(num_ftrs, num_classes)
        # Handle the primary net
        num_ftrs = model_ft.fc.in_features
        model_ft.fc = nn.Linear(num_ftrs,num_classes)
        input_size = 299

    else:
        print("Invalid model name, exiting...")
        exit()
    return model_ft, input_size

# %% [markdown]
# You can change your backbone network, here are 4 different networks, each network also has sevaral versions. Considering the limited training data, we used the ImageNet pre-training model for fine-tuning. This can speed up the convergence of the model and improve the accuracy.
#
# There is one thing you need to pay attention to, the input size of Inception is different from the others (299x299), you need to change the setting of compute_img_mean_std() function

# %%
# resnet,vgg,densenet,inception
model_name = 'densenet'
num_classes = 7
feature_extract = False
# Initialize the model for this run
model_ft, input_size = initialize_model(model_name, num_classes, feature_extract, use_pretrained=True)

if torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu") #on laptop, use cpu torch

# device = torch.device('cuda:0')
print(device)
# Put the model on the device:
model = model_ft.to(device)
# Out:
# cpu

# %%
# norm_mean = (0.49139968, 0.48215827, 0.44653124)
# norm_std = (0.24703233, 0.24348505, 0.26158768)
# define the transformation of the train images.
train_transform = transforms.Compose([transforms.Resize((input_size,input_size)),transforms.RandomHorizontalFlip(),
                                      transforms.RandomVerticalFlip(),transforms.RandomRotation(20),
                                      transforms.ColorJitter(brightness=0.1, contrast=0.1, hue=0.1),
                                        transforms.ToTensor(), transforms.Normalize(norm_mean, norm_std)])
# define the transformation of the val images.
val_transform = transforms.Compose([transforms.Resize((input_size,input_size)), transforms.ToTensor(),
                                    transforms.Normalize(norm_mean, norm_std)])

# %%
# Define a pytorch dataloader for this dataset
class HAM10000(Dataset):
    def __init__(self, df, transform=None):
        self.df = df
        self.transform = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, index):
        # Load data and get label
        X = Image.open(self.df['path'][index])
        y = torch.tensor(int(self.df['cell_type_idx'][index]))

        if self.transform:
            X = self.transform(X)

        return X, y

# %%
# Define the training set using the table train_df and using our defined transitions (train_transform)
training_set = HAM10000(df_train, transform=train_transform)
#NOTE: previously set batch_size to 32
train_loader = DataLoader(training_set, shuffle=True)
#train_loader = DataLoader(training_set, batch_size=1, shuffle=True, num_workers=4)

# Same for the validation set:
validation_set = HAM10000(df_val, transform=train_transform)
val_loader = DataLoader(validation_set, shuffle=False)
#val_loader = DataLoader(validation_set, batch_size=1, shuffle=False, num_workers=4)

# %%
# we use Adam optimizer, use cross entropy loss as our loss function
optimizer = optim.Adam(model.parameters(), lr=1e-3)
criterion = nn.CrossEntropyLoss().to(device)

# %% [markdown]
# ## Step 3. Model training

# %%
# Used during training, to compute the loss and accuracy
class AverageMeter(object):
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %%
total_loss_train, total_acc_train = [],[]
def train(train_loader, model, criterion, optimizer, epoch):
    model.train()
    train_loss = AverageMeter()
    train_acc = AverageMeter()
    curr_iter = (epoch - 1) * len(train_loader)
    for i, data in enumerate(train_loader):
        images, labels = data
        N = images.size(0)
        #print('image shape:',images.size(0), 'label shape',labels.size(0))
        images = Variable(images).to(device)
        labels = Variable(labels).to(device)

        optimizer.zero_grad()
        outputs = model(images)

        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        prediction = outputs.max(1, keepdim=True)[1]
        train_acc.update(prediction.eq(labels.view_as(prediction)).sum().item()/N)
        train_loss.update(loss.item())
        curr_iter += 1
        if (i + 1) % 100 == 0:
            print('[epoch %d], [iter %d / %d], [train loss %.5f], [train acc %.5f]' % (
                epoch, i + 1, len(train_loader), train_loss.avg, train_acc.avg))
            total_loss_train.append(train_loss.avg)
            total_acc_train.append(train_acc.avg)
    return train_loss.avg, train_acc.avg

# %%
def validate(val_loader, model, criterion, optimizer, epoch):
    model.eval()
    val_loss = AverageMeter()
    val_acc = AverageMeter()
    with torch.no_grad():
        for i, data in enumerate(val_loader):
            images, labels = data
            N = images.size(0)
            images = Variable(images).to(device)
            labels = Variable(labels).to(device)

            outputs = model(images)
            prediction = outputs.max(1, keepdim=True)[1]

            val_acc.update(prediction.eq(labels.view_as(prediction)).sum().item()/N)

            val_loss.update(criterion(outputs, labels).item())

    print('------------------------------------------------------------')
    print('[epoch %d], [val loss %.5f], [val acc %.5f]' % (epoch, val_loss.avg, val_acc.avg))
    print('------------------------------------------------------------')
    return val_loss.avg, val_acc.avg

# %%
epoch_num = 10
best_val_acc = 0
total_loss_val, total_acc_val = [],[]
for epoch in range(1, epoch_num+1):
    loss_train, acc_train = train(train_loader, model, criterion, optimizer, epoch)
    loss_val, acc_val = validate(val_loader, model, criterion, optimizer, epoch)
    total_loss_val.append(loss_val)
    total_acc_val.append(acc_val)
    if acc_val > best_val_acc:
        best_val_acc = acc_val
        print('*****************************************************')
        print('best record: [epoch %d], [val loss %.5f], [val acc %.5f]' % (epoch, loss_val, acc_val))
        print('*****************************************************')
# Out:
# [epoch 1], [iter 100 / 3127], [train loss 2.29561], [train acc 0.08000]
# [epoch 1], [iter 200 / 3127], [train loss 2.19931], [train acc 0.15500]
# [epoch 1], [iter 300 / 3127], [train loss 2.18325], [train acc 0.15000]
# [epoch 1], [iter 400 / 3127], [train loss 2.13940], [train acc 0.16250]
# [epoch 1], [iter 500 / 3127], [train loss 2.14568], [train acc 0.15400]
# [epoch 1], [iter 600 / 3127], [train loss 2.14581], [train acc 0.14833]
# [epoch 1], [iter 700 / 3127], [train loss 2.13724], [train acc 0.15286]
# [epoch 1], [iter 800 / 3127], [train loss 2.12747], [train acc 0.14750]
# [epoch 1], [iter 900 / 3127], [train loss 2.12911], [train acc 0.14333]
# [epoch 1], [iter 1000 / 3127], [train loss 2.13106], [train acc 0.14100]
# [epoch 1], [iter 1100 / 3127], [train loss 2.13186], [train acc 0.13636]
# [epoch 1], [iter 1200 / 3127], [train loss 2.13000], [train acc 0.13667]
# [epoch 1], [iter 1300 / 3127], [train loss 2.12979], [train acc 0.13769]
# [epoch 1], [iter 1400 / 3127], [train loss 2.12930], [train acc 0.13857]
# [epoch 1], [iter 1500 / 3127], [train loss 2.12586], [train acc 0.13933]
# [epoch 1], [iter 1600 / 3127], [train loss 2.11841], [train acc 0.14062]
# [epoch 1], [iter 1700 / 3127], [train loss 2.11189], [train acc 0.14176]
# [epoch 1], [iter 1800 / 3127], [train loss 2.11148], [train acc 0.14167]
# [epoch 1], [iter 1900 / 3127], [train loss 2.11380], [train acc 0.14263]
# [epoch 1], [iter 2000 / 3127], [train loss 2.11292], [train acc 0.13950]
# [epoch 1], [iter 2100 / 3127], [train loss 2.11126], [train acc 0.13952]
# [epoch 1], [iter 2200 / 3127], [train loss 2.10904], [train acc 0.14091]
# [epoch 1], [iter 2300 / 3127], [train loss 2.10477], [train acc 0.14174]
# [epoch 1], [iter 2400 / 3127], [train loss 2.10403], [train acc 0.14292]
# [epoch 1], [iter 2500 / 3127], [train loss 2.10157], [train acc 0.14280]
# [epoch 1], [iter 2600 / 3127], [train loss 2.09823], [train acc 0.14269]
# [epoch 1], [iter 2700 / 3127], [train loss 2.09733], [train acc 0.14333]
# [epoch 1], [iter 2800 / 3127], [train loss 2.09688], [train acc 0.14250]
# [epoch 1], [iter 2900 / 3127], [train loss 2.09554], [train acc 0.14345]
# [epoch 1], [iter 3000 / 3127], [train loss 2.09430], [train acc 0.14233]
# [epoch 1], [iter 3100 / 3127], [train loss 2.09406], [train acc 0.14290]
# ------------------------------------------------------------
# [epoch 1], [val loss 3.34706], [val acc 0.69634]
# ------------------------------------------------------------
# *****************************************************
# best record: [epoch 1], [val loss 3.34706], [val acc 0.69634]
# *****************************************************
# [epoch 2], [iter 100 / 3127], [train loss 2.03090], [train acc 0.16000]
# [epoch 2], [iter 200 / 3127], [train loss 2.05941], [train acc 0.13000]
# [epoch 2], [iter 300 / 3127], [train loss 2.05688], [train acc 0.12000]
# [epoch 2], [iter 400 / 3127], [train loss 2.05503], [train acc 0.13000]
# [epoch 2], [iter 500 / 3127], [train loss 2.04054], [train acc 0.15200]
# [epoch 2], [iter 600 / 3127], [train loss 2.04915], [train acc 0.14333]
# [epoch 2], [iter 700 / 3127], [train loss 2.04499], [train acc 0.14000]
# [epoch 2], [iter 800 / 3127], [train loss 2.04207], [train acc 0.14875]
# [epoch 2], [iter 900 / 3127], [train loss 2.03828], [train acc 0.14889]
# [epoch 2], [iter 1000 / 3127], [train loss 2.03860], [train acc 0.14700]
# [epoch 2], [iter 1100 / 3127], [train loss 2.03936], [train acc 0.14727]
# [epoch 2], [iter 1200 / 3127], [train loss 2.03499], [train acc 0.14417]
# [epoch 2], [iter 1300 / 3127], [train loss 2.03533], [train acc 0.14769]
# [epoch 2], [iter 1400 / 3127], [train loss 2.03543], [train acc 0.14571]
# [epoch 2], [iter 1500 / 3127], [train loss 2.03495], [train acc 0.14467]
# [epoch 2], [iter 1600 / 3127], [train loss 2.03413], [train acc 0.14938]
# [epoch 2], [iter 1700 / 3127], [train loss 2.03474], [train acc 0.14941]
# [epoch 2], [iter 1800 / 3127], [train loss 2.03307], [train acc 0.15056]
# [epoch 2], [iter 1900 / 3127], [train loss 2.02640], [train acc 0.15105]
# [epoch 2], [iter 2000 / 3127], [train loss 2.02374], [train acc 0.15350]
# [epoch 2], [iter 2100 / 3127], [train loss 2.02635], [train acc 0.15095]
# [epoch 2], [iter 2200 / 3127], [train loss 2.02531], [train acc 0.15182]
# [epoch 2], [iter 2300 / 3127], [train loss 2.02197], [train acc 0.15130]
# [epoch 2], [iter 2400 / 3127], [train loss 2.01927], [train acc 0.15333]
# [epoch 2], [iter 2500 / 3127], [train loss 2.01927], [train acc 0.15160]
# [epoch 2], [iter 2600 / 3127], [train loss 2.02038], [train acc 0.15000]
# [epoch 2], [iter 2700 / 3127], [train loss 2.01995], [train acc 0.14815]
# [epoch 2], [iter 2800 / 3127], [train loss 2.01825], [train acc 0.14857]
# [epoch 2], [iter 2900 / 3127], [train loss 2.01898], [train acc 0.14828]
# [epoch 2], [iter 3000 / 3127], [train loss 2.01780], [train acc 0.15033]
# [epoch 2], [iter 3100 / 3127], [train loss 2.01571], [train acc 0.15097]
# ------------------------------------------------------------
# [epoch 2], [val loss 1.82079], [val acc 0.60733]
# ------------------------------------------------------------
# [epoch 3], [iter 100 / 3127], [train loss 2.00356], [train acc 0.11000]
# [epoch 3], [iter 200 / 3127], [train loss 2.04186], [train acc 0.10500]
# [epoch 3], [iter 300 / 3127], [train loss 2.03494], [train acc 0.10667]
# [epoch 3], [iter 400 / 3127], [train loss 2.02736], [train acc 0.12500]
# [epoch 3], [iter 500 / 3127], [train loss 2.03138], [train acc 0.12600]
# [epoch 3], [iter 600 / 3127], [train loss 2.03163], [train acc 0.12500]
# [epoch 3], [iter 700 / 3127], [train loss 2.02547], [train acc 0.12714]
# [epoch 3], [iter 800 / 3127], [train loss 2.02466], [train acc 0.13125]
# [epoch 3], [iter 900 / 3127], [train loss 2.02693], [train acc 0.12667]
# [epoch 3], [iter 1000 / 3127], [train loss 2.02183], [train acc 0.12800]
# [epoch 3], [iter 1100 / 3127], [train loss 2.01897], [train acc 0.12818]
# [epoch 3], [iter 1200 / 3127], [train loss 2.01620], [train acc 0.13333]
# [epoch 3], [iter 1300 / 3127], [train loss 2.01629], [train acc 0.13231]
# [epoch 3], [iter 1400 / 3127], [train loss 2.01411], [train acc 0.13500]
# [epoch 3], [iter 1500 / 3127], [train loss 2.01581], [train acc 0.13400]
# [epoch 3], [iter 1600 / 3127], [train loss 2.01161], [train acc 0.13687]
# [epoch 3], [iter 1700 / 3127], [train loss 2.01057], [train acc 0.13588]
# [epoch 3], [iter 1800 / 3127], [train loss 2.00896], [train acc 0.13611]
# [epoch 3], [iter 1900 / 3127], [train loss 2.00772], [train acc 0.13579]
# [epoch 3], [iter 2000 / 3127], [train loss 2.00870], [train acc 0.13500]
# [epoch 3], [iter 2100 / 3127], [train loss 2.00704], [train acc 0.13714]
# [epoch 3], [iter 2200 / 3127], [train loss 2.00696], [train acc 0.13864]
# [epoch 3], [iter 2300 / 3127], [train loss 2.00572], [train acc 0.13957]
# [epoch 3], [iter 2400 / 3127], [train loss 2.00471], [train acc 0.13875]
# [epoch 3], [iter 2500 / 3127], [train loss 2.00349], [train acc 0.13880]
# [epoch 3], [iter 2600 / 3127], [train loss 2.00190], [train acc 0.14077]
# [epoch 3], [iter 2700 / 3127], [train loss 2.00156], [train acc 0.14074]
# [epoch 3], [iter 2800 / 3127], [train loss 2.00078], [train acc 0.14286]
# [epoch 3], [iter 2900 / 3127], [train loss 2.00054], [train acc 0.14276]
# [epoch 3], [iter 3000 / 3127], [train loss 1.99888], [train acc 0.14267]
# [epoch 3], [iter 3100 / 3127], [train loss 1.99713], [train acc 0.14484]
# ------------------------------------------------------------
# [epoch 3], [val loss 69.63276], [val acc 0.01571]
# ------------------------------------------------------------
# [epoch 9], [iter 2800 / 3127], [train loss 1.56087], [train acc 0.38214]
# [epoch 9], [iter 2900 / 3127], [train loss 1.55427], [train acc 0.38483]
# [epoch 9], [iter 3000 / 3127], [train loss 1.54726], [train acc 0.38633]
# [epoch 9], [iter 3100 / 3127], [train loss 1.54145], [train acc 0.38871]
# ------------------------------------------------------------
# [epoch 9], [val loss 6.37970], [val acc 0.47120]
# ------------------------------------------------------------
# [epoch 10], [iter 100 / 3127], [train loss 1.29647], [train acc 0.54000]
# [epoch 10], [iter 200 / 3127], [train loss 1.38536], [train acc 0.48500]
# [epoch 10], [iter 300 / 3127], [train loss 1.43220], [train acc 0.46333]
# [epoch 10], [iter 400 / 3127], [train loss 1.46187], [train acc 0.45750]
# [epoch 10], [iter 500 / 3127], [train loss 1.43025], [train acc 0.45800]
# [epoch 10], [iter 600 / 3127], [train loss 1.42816], [train acc 0.45167]
# [epoch 10], [iter 700 / 3127], [train loss 1.42333], [train acc 0.45286]
# [epoch 10], [iter 800 / 3127], [train loss 1.43200], [train acc 0.44500]
# [epoch 10], [iter 900 / 3127], [train loss 1.42591], [train acc 0.44444]
# [epoch 10], [iter 1000 / 3127], [train loss 1.43813], [train acc 0.44200]
# [epoch 10], [iter 1100 / 3127], [train loss 1.43507], [train acc 0.44545]
# [epoch 10], [iter 1200 / 3127], [train loss 1.43086], [train acc 0.44333]
# [epoch 10], [iter 1300 / 3127], [train loss 1.44011], [train acc 0.43769]
# [epoch 10], [iter 1400 / 3127], [train loss 1.43069], [train acc 0.44143]
# [epoch 10], [iter 1500 / 3127], [train loss 1.42218], [train acc 0.43933]
# [epoch 10], [iter 1600 / 3127], [train loss 1.42455], [train acc 0.43812]
# [epoch 10], [iter 1700 / 3127], [train loss 1.42004], [train acc 0.43941]
# [epoch 10], [iter 1800 / 3127], [train loss 1.40526], [train acc 0.44444]
# [epoch 10], [iter 1900 / 3127], [train loss 1.41411], [train acc 0.43895]
# [epoch 10], [iter 2000 / 3127], [train loss 1.41072], [train acc 0.44300]
# [epoch 10], [iter 2100 / 3127], [train loss 1.40642], [train acc 0.44667]
# [epoch 10], [iter 2200 / 3127], [train loss 1.39669], [train acc 0.45045]
# [epoch 10], [iter 2300 / 3127], [train loss 1.40201], [train acc 0.44783]
# [epoch 10], [iter 2400 / 3127], [train loss 1.39766], [train acc 0.44625]
# [epoch 10], [iter 2500 / 3127], [train loss 1.39095], [train acc 0.44720]
# [epoch 10], [iter 2600 / 3127], [train loss 1.38912], [train acc 0.44769]
# [epoch 10], [iter 2700 / 3127], [train loss 1.38876], [train acc 0.44852]
# [epoch 10], [iter 2800 / 3127], [train loss 1.38863], [train acc 0.44643]
# [epoch 10], [iter 2900 / 3127], [train loss 1.38317], [train acc 0.45034]
# [epoch 10], [iter 3000 / 3127], [train loss 1.37868], [train acc 0.45133]
# [epoch 10], [iter 3100 / 3127], [train loss 1.37278], [train acc 0.45419]
# ------------------------------------------------------------
# [epoch 10], [val loss 22.21402], [val acc 0.23560]
# ------------------------------------------------------------

# %% [markdown]
# ## Step 4. Model evaluation

# %%
fig = plt.figure(num = 2)
fig1 = fig.add_subplot(2,1,1)
fig2 = fig.add_subplot(2,1,2)
fig1.plot(total_loss_train, label = 'training loss')
fig1.plot(total_acc_train, label = 'training accuracy')
fig2.plot(np.array(total_loss_val) / (np.max(np.array(total_loss_val))), label = 'validation loss normalized')
fig2.plot(total_acc_val, label = 'validation accuracy')
plt.legend()
plt.show()

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
model.eval()
y_label = []
y_predict = []
with torch.no_grad():
    for i, data in enumerate(val_loader):
        images, labels = data
        N = images.size(0)
        images = Variable(images).to(device)
        outputs = model(images)
        prediction = outputs.max(1, keepdim=True)[1]
        y_label.extend(labels.cpu().numpy())
        y_predict.extend(prediction.cpu().numpy().T)
        #y_predict.extend(np.squeeze(prediction.cpu().numpy().T))

# compute the confusion matrix
confusion_mtx = confusion_matrix(y_label, y_predict)
# plot the confusion matrix
plot_labels = ['akiec', 'bcc', 'bkl', 'df', 'nv', 'vasc','mel']
plot_confusion_matrix(confusion_mtx, plot_labels)

# %%
#y_predict.extend(prediction.cpu().numpy().T)
#print(np.squeeze(prediction.cpu().numpy().T))
#np.squeeze(prediction.cpu().numpy().T)
#y_predict.extend(np.array([3,4,5]))

# %%
# Generate a classification report
report = classification_report(y_label, y_predict, target_names=plot_labels)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#        akiec       0.00      0.00      0.00       1.0
#          bcc       0.00      0.00      0.00       3.0
#          bkl       0.00      0.00      0.00       6.0
#           df       0.00      0.00      0.00       0.0
#           nv       0.00      0.00      0.00      26.0
#         vasc       0.00      0.00      0.00       1.0
#          mel       0.00      0.00      0.00       3.0
#
#     accuracy                           0.00      40.0
#    macro avg       0.00      0.00      0.00      40.0
# weighted avg       0.00      0.00      0.00      40.0
# C:\Users\elias\miniconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\elias\miniconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\elias\miniconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\elias\miniconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\elias\miniconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\elias\miniconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
label_frac_error = 1 - np.diag(confusion_mtx) / np.sum(confusion_mtx, axis=1)
plt.bar(np.arange(7),label_frac_error)
plt.xlabel('True Label')
plt.ylabel('Fraction classified incorrectly')
# Out:
# C:\Users\elias\AppData\Local\Temp/ipykernel_2092/1127229655.py:1: RuntimeWarning: invalid value encountered in true_divide
#   label_frac_error = 1 - np.diag(confusion_mtx) / np.sum(confusion_mtx, axis=1)
# Text(0, 0.5, 'Fraction classified incorrectly')

# %% [markdown]
# ## Conclusion

# %% [markdown]
# I tried to train with different network structures. When using Densenet-121, the average accuracy of 7 classes on the validation set can reach 92% in 10 epochs. We also calculated the confusion matrix for all classes and the F1-score for each class, which is a more comprehensive indicator that can take into account both the precision and recall of the classification model.Our model can achieve more than 90% on the F1-score indicator.
#
# Due to limited time, we did not spend much time on model training. By increasing in training epochs, adjustmenting of model hyperparameters, and attempting at different networks may further enhance the performance of the model.

# %% [markdown]
# ## Next plan

# %% [markdown]
# How to use image data and patient case data at the same time, my plan is to use CNN to extract features from images, use xgboost to convert medical records into vectors and then concat them with CNN network full-layer features. Two branch networks are trained simultaneously using a loss function. We can refer to the methods used in the advertising CTR estimation task.
